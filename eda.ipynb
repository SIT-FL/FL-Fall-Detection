# %% [markdown]
# # Exploratory Data Analysis of Fall-Detection Dataset

# %%
from mat4py import loadmat
data = loadmat('dataset/subject_01/fall/fall1.mat')

# %%
data.keys()
# Out:
# dict_keys(['time', 'w', 'x', 'y', 'z', 'droll', 'dpitch', 'dyaw', 'ax', 'ay', 'az', 'heart'])

# %%
data
# Out:
# {'time': [[2018.0, 5.0, 11.0, 13.0, 17.0, 2.825],
#   [2018.0, 5.0, 11.0, 13.0, 17.0, 2.8289999999999997],
#   [2018.0, 5.0, 11.0, 13.0, 17.0, 2.847],
#   [2018.0, 5.0, 11.0, 13.0, 17.0, 2.885],
#   [2018.0, 5.0, 11.0, 13.0, 17.0, 2.9050000000000002],
#   [2018.0, 5.0, 11.0, 13.0, 17.0, 2.909],
#   [2018.0, 5.0, 11.0, 13.0, 17.0, 2.925],
#   [2018.0, 5.0, 11.0, 13.0, 17.0, 2.961],
#   [2018.0, 5.0, 11.0, 13.0, 17.0, 2.981],
#   [2018.0, 5.0, 11.0, 13.0, 17.0, 2.985],
#   [2018.0, 5.0, 11.0, 13.0, 17.0, 3.006],
#   [2018.0, 5.0, 11.0, 13.0, 17.0, 3.024],
#   [2018.0, 5.0, 11.0, 13.0, 17.0, 3.064],
#   [2018.0, 5.0, 11.0, 13.0, 17.0, 3.083],
#   [2018.0, 5.0, 11.0, 13.0, 17.0, 3.087],
#   [2018.0, 5.0, 11.0, 13.0, 17.0, 3.108],
#   [2018.0, 5.0, 11.0, 13.0, 17.0, 3.128],
#   [2018.0, 5.0, 11.0, 13.0, 17.0, 3.147],
#   [2018.0, 5.0, 11.0, 13.0, 17.0, 3.167],
#   [2018.0, 5.0, 11.0, 13.0, 17.0, 3.188],
#   [2018.0, 5.0, 11.0, 13.0, 17.0, 3.225],
# ...
